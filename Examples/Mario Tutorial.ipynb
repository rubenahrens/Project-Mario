# %% [markdown]
# # 1. Setup Mario

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# !pip freeze
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym_super_mario_bros==7.3.0 in /home/daniel/.local/lib/python3.10/site-packages (7.3.0)
# Requirement already satisfied: nes_py in /home/daniel/.local/lib/python3.10/site-packages (8.2.1)
# Requirement already satisfied: tqdm>=4.48.2 in /home/daniel/.local/lib/python3.10/site-packages (from nes_py) (4.64.0)
# Requirement already satisfied: gym>=0.17.2 in /home/daniel/.local/lib/python3.10/site-packages (from nes_py) (0.21.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/daniel/.local/lib/python3.10/site-packages (from nes_py) (1.21.6)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in /home/daniel/.local/lib/python3.10/site-packages (from nes_py) (1.5.21)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/daniel/.local/lib/python3.10/site-packages (from gym>=0.17.2->nes_py) (2.0.0)

# %%
# Import the game
import gym
# Import the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Import the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# Setup game
env = gym.make('SuperMarioBros-1-1-v0')#, apply_api_compatibility=True, render_mode="human")
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# Create a flag - restart or not
done = True
# Loop through each frame in the game
for step in range(1000): 
    # Start the game to begin with 
    if done: 
        # Start the gamee
        state = env.reset()
    # Do random actions
    state, reward, done, info = env.step(env.action_space.sample())
    # Show the game on the screen
    env.render()
# Close the game
env.close()
# Out:
# /home/daniel/.local/lib/python3.10/site-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256

# %% [markdown]
# # 2. Preprocess Environment

# %%
# Install pytorch
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio===0.11.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# Install stable baselines for RL stuff
# !pip install setuptools==57.1.0 pyee==8.2.2
# !pip install 'stable-baselines3[extra]'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.11.0+cu113 in /home/daniel/.local/lib/python3.10/site-packages (1.11.0+cu113)
# Requirement already satisfied: torchvision==0.12.0+cu113 in /home/daniel/.local/lib/python3.10/site-packages (0.12.0+cu113)
# Requirement already satisfied: torchaudio===0.11.0+cu113 in /home/daniel/.local/lib/python3.10/site-packages (0.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/lib/python3.10/site-packages (from torch==1.11.0+cu113) (4.5.0)
# Requirement already satisfied: requests in /usr/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (2.28.2)
# Requirement already satisfied: numpy in /home/daniel/.local/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (9.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (1.26.13)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: setuptools==57.1.0 in /home/daniel/.local/lib/python3.10/site-packages (57.1.0)
# Requirement already satisfied: pyee==8.2.2 in /home/daniel/.local/lib/python3.10/site-packages (8.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in /home/daniel/.local/lib/python3.10/site-packages (1.8.0)
# Requirement already satisfied: gym==0.21 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: pandas in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: matplotlib in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (3.5.2)
# Requirement already satisfied: numpy in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.21.6)
# Requirement already satisfied: importlib-metadata~=4.13 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: torch>=1.11 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.11.0+cu113)
# Requirement already satisfied: cloudpickle in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: pillow in /usr/lib/python3.10/site-packages (from stable-baselines3[extra]) (9.4.0)
# Requirement already satisfied: psutil in /usr/lib/python3.10/site-packages (from stable-baselines3[extra]) (5.9.4)
# Requirement already satisfied: ale-py==0.7.4 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tqdm in /home/daniel/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: rich in /usr/lib/python3.10/site-packages (from stable-baselines3[extra]) (13.3.3)
# Requirement already satisfied: importlib-resources in /home/daniel/.local/lib/python3.10/site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: click in /usr/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.1.3)
# Requirement already satisfied: requests in /usr/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.28.2)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/daniel/.local/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3.10/site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.16.2)
# Requirement already satisfied: grpcio>=1.48.2 in /home/daniel/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.54.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.21.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/daniel/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (57.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/daniel/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/daniel/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.40.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: absl-py>=0.4 in /home/daniel/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: typing-extensions in /usr/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/daniel/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/daniel/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /home/daniel/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2022.7.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/daniel/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/daniel/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
# Import Frame Stacker Wrapper and GrayScaling Wrapper
from gym.wrappers import GrayScaleObservation
# Import Vectorization Wrappers
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
# Import Matplotlib to show the impact of frame stacking
from matplotlib import pyplot as plt

# %%
# 1. Create the base environment
env = gym.make('SuperMarioBrosRandomStages-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %%
state = env.reset()

# %%
state, reward, done, info = env.step([5])

# %%
plt.figure(figsize=(20,16))
for idx in range(state.shape[3]):
    plt.subplot(1,4,idx+1)
    plt.imshow(state[0][:,:,idx])
plt.show()

# %% [markdown]
# # 3. Train the RL Model

# %%
# Import os for file path management
import os 
# Import PPO for algos
from stable_baselines3 import PPO
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
# This is the AI model started
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, 
            n_steps=512)

# %%
# Train the AI model, this is where the AI model starts to learn
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# /home/daniel/.local/lib/python3.10/site-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 269 |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 160           |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 3.7710415e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0151       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 98.6          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000298     |
# |    value_loss           | 365           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 3            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 6.341422e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0439       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 106          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000333    |
# |    value_loss           | 357          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 135           |
# |    iterations           | 4             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00019729265 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0155       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 102           |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00062      |
# |    value_loss           | 329           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 132           |
# |    iterations           | 5             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 0.00016418938 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.295         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 171           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000424     |
# |    value_loss           | 394           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 129           |
# |    iterations           | 6             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00023003598 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.172        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.144         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000886     |
# |    value_loss           | 2.51          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 128           |
# |    iterations           | 7             |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 5.4147327e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0212        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0962        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000391     |
# |    value_loss           | 1.7           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 8            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 6.257126e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.357        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.154        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00041     |
# |    value_loss           | 1.11         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 126           |
# |    iterations           | 9             |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 3.0686264e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0114       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0957        |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00031      |
# |    value_loss           | 1.06          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 125           |
# |    iterations           | 10            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 1.1770404e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.402         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0813        |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000112     |
# |    value_loss           | 0.811         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 124           |
# |    iterations           | 11            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 1.5753205e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.121         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.109         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000147     |
# |    value_loss           | 0.668         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 124           |
# |    iterations           | 12            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 2.1435553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0908       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.214         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000242     |
# |    value_loss           | 0.75          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 13           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 6656         |
# | train/                  |              |
# |    approx_kl            | 8.198083e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0375      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.095        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -5.46e-05    |
# |    value_loss           | 0.388        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 14            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 4.1285064e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0473       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0722        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000444     |
# |    value_loss           | 0.327         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 15            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 2.3352099e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0372       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.117         |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000247     |
# |    value_loss           | 0.314         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 16            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.3749075e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00745       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.081         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00026      |
# |    value_loss           | 0.253         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 17           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 5.249004e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0278      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0826       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000579    |
# |    value_loss           | 0.237        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 18           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 3.603159e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00421     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0635       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000363    |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 19            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 4.0726736e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00219       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.066         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000403     |
# |    value_loss           | 0.2           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 20           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 1.565984e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.015        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0821       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000206    |
# |    value_loss           | 0.285        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 21          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 3.53473e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.064       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 101         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -9.02e-05   |
# |    value_loss           | 260         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 22            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 3.0033523e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.124         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.162         |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000351     |
# |    value_loss           | 1.25          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 23            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 2.5147805e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0172        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0745        |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000203     |
# |    value_loss           | 0.843         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 24            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 3.0409894e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0157        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0821        |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000318     |
# |    value_loss           | 0.54          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 25            |
# |    time_elapsed         | 105           |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 5.4225326e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0151       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.117         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.0006       |
# |    value_loss           | 0.355         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 26           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 3.249629e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00268      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0947       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 0.41         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 27            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 2.2271299e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0382       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.119         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000225     |
# |    value_loss           | 0.325         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 28          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 2.20699e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0829      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000214   |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 29            |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 1.2508011e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0449        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0757        |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -7.49e-05     |
# |    value_loss           | 0.202         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 30            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 5.6633726e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0535       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.11          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.65e-05     |
# |    value_loss           | 0.29          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 31           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 15872        |
# | train/                  |              |
# |    approx_kl            | 3.260572e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0533      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.157        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000391    |
# |    value_loss           | 0.246        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 32            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 4.7225156e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00908      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0693        |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000477     |
# |    value_loss           | 0.174         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 33            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 16896         |
# | train/                  |               |
# |    approx_kl            | 1.0351534e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0313       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0612        |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -9.45e-05     |
# |    value_loss           | 0.121         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 34            |
# |    time_elapsed         | 143           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 4.3172855e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00675       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0702        |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 0.173         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 35            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 0.00010676042 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0131       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.072         |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 0.162         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 36            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 3.9173174e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.796         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 3.66          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000623     |
# |    value_loss           | 11.6          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 37           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0016742308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | -0.00036     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.26         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000594     |
# |    value_loss           | 230          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 38           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0010252461 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 142          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 389          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 39           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 0.0002938431 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | -0.241       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 152          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000476     |
# |    value_loss           | 427          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 40            |
# |    time_elapsed         | 170           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00017965469 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0174       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.632         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000415     |
# |    value_loss           | 6.09          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 41           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 20992        |
# | train/                  |              |
# |    approx_kl            | 5.581067e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.282        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.25         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00055      |
# |    value_loss           | 3.59         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 42            |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 4.3081003e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0513       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.249         |
# |    n_updates            | 410           |
# |    policy_gradient_loss | 5.7e-05       |
# |    value_loss           | 2.11          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 120            |
# |    iterations           | 43             |
# |    time_elapsed         | 183            |
# |    total_timesteps      | 22016          |
# | train/                  |                |
# |    approx_kl            | 0.000114311115 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.93          |
# |    explained_variance   | 0.235          |
# |    learning_rate        | 1e-06          |
# |    loss                 | 29.1           |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -0.000238      |
# |    value_loss           | 108            |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 44            |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.00035130652 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.625         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.552         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | 0.000224      |
# |    value_loss           | 10.2          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 45            |
# |    time_elapsed         | 191           |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 0.00025572057 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.0112        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.232         |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000242     |
# |    value_loss           | 6.24          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 120            |
# |    iterations           | 46             |
# |    time_elapsed         | 196            |
# |    total_timesteps      | 23552          |
# | train/                  |                |
# |    approx_kl            | 0.000115472474 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.93          |
# |    explained_variance   | 0.64           |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.335          |
# |    n_updates            | 450            |
# |    policy_gradient_loss | 0.000612       |
# |    value_loss           | 4.06           |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 47            |
# |    time_elapsed         | 200           |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 6.9035916e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.787         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.182         |
# |    n_updates            | 460           |
# |    policy_gradient_loss | 1.19e-05      |
# |    value_loss           | 2.52          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 48            |
# |    time_elapsed         | 204           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 3.8203318e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.235         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.145         |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.00034       |
# |    value_loss           | 1.58          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 49          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 25088       |
# | train/                  |             |
# |    approx_kl            | 3.78947e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.201       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 6.66e-05    |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 50            |
# |    time_elapsed         | 213           |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 6.4497115e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.395         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.111         |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000467     |
# |    value_loss           | 0.654         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 51            |
# |    time_elapsed         | 217           |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 0.00011155754 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.025        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0701        |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000557     |
# |    value_loss           | 0.483         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 52          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 2.96426e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0913      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00011     |
# |    value_loss           | 0.416       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 53           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 27136        |
# | train/                  |              |
# |    approx_kl            | 2.496154e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.059        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0558       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -8.99e-05    |
# |    value_loss           | 0.271        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 54            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 4.4104527e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.00834       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0627        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000237     |
# |    value_loss           | 0.29          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 55           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 28160        |
# | train/                  |              |
# |    approx_kl            | 0.0022167703 |
# |    clip_fraction        | 0.00449      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 207          |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 503          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 56           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0002893795 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.0192       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 70.8         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.000346     |
# |    value_loss           | 146          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 57            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 0.00079133816 |
# |    clip_fraction        | 0.00254       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | -0.00816      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.02          |
# |    n_updates            | 560           |
# |    policy_gradient_loss | 0.00117       |
# |    value_loss           | 21.1          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 58            |
# |    time_elapsed         | 247           |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 0.00019160041 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.83         |
# |    explained_variance   | 0.0505        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 24.4          |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000587     |
# |    value_loss           | 76.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 59           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 30208        |
# | train/                  |              |
# |    approx_kl            | 0.0008134289 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.0517       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.956        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000589    |
# |    value_loss           | 13.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 60           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0007874365 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | -0.00675     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.497        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000709    |
# |    value_loss           | 8.46         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 61           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 0.0004202926 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | -0.0268      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.385        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.000656     |
# |    value_loss           | 5.44         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 119           |
# |    iterations           | 62            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 0.00018810458 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.88         |
# ...
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1            |
# |    n_updates            | 19330        |
# |    policy_gradient_loss | -0.000737    |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1935         |
# |    time_elapsed         | 8352         |
# |    total_timesteps      | 990720       |
# | train/                  |              |
# |    approx_kl            | 0.0013354864 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.543        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 14.2         |
# |    n_updates            | 19340        |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 35.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1936          |
# |    time_elapsed         | 8357          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00012034003 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.941        |
# |    explained_variance   | 0.272         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 47.1          |
# |    n_updates            | 19350         |
# |    policy_gradient_loss | 0.000292      |
# |    value_loss           | 167           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1937          |
# |    time_elapsed         | 8361          |
# |    total_timesteps      | 991744        |
# | train/                  |               |
# |    approx_kl            | 0.00088027946 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.855        |
# |    explained_variance   | 0.946         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 15.2          |
# |    n_updates            | 19360         |
# |    policy_gradient_loss | -0.000777     |
# |    value_loss           | 63.6          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1938         |
# |    time_elapsed         | 8365         |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0015740929 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.664        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 29.7         |
# |    n_updates            | 19370        |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 99.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1939         |
# |    time_elapsed         | 8370         |
# |    total_timesteps      | 992768       |
# | train/                  |              |
# |    approx_kl            | 0.0016292055 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.88        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 29.5         |
# |    n_updates            | 19380        |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1940         |
# |    time_elapsed         | 8374         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0008603794 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 58.2         |
# |    n_updates            | 19390        |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 221          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 1941        |
# |    time_elapsed         | 8378        |
# |    total_timesteps      | 993792      |
# | train/                  |             |
# |    approx_kl            | 0.001919491 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 23.6        |
# |    n_updates            | 19400       |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 78.1        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1942          |
# |    time_elapsed         | 8382          |
# |    total_timesteps      | 994304        |
# | train/                  |               |
# |    approx_kl            | 0.00075648923 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.86          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 22.3          |
# |    n_updates            | 19410         |
# |    policy_gradient_loss | -0.00031      |
# |    value_loss           | 103           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1943         |
# |    time_elapsed         | 8387         |
# |    total_timesteps      | 994816       |
# | train/                  |              |
# |    approx_kl            | 0.0029758757 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 47           |
# |    n_updates            | 19420        |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 136          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1944         |
# |    time_elapsed         | 8391         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0001262218 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 52.8         |
# |    n_updates            | 19430        |
# |    policy_gradient_loss | -0.000449    |
# |    value_loss           | 207          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 1945       |
# |    time_elapsed         | 8395       |
# |    total_timesteps      | 995840     |
# | train/                  |            |
# |    approx_kl            | 0.00906535 |
# |    clip_fraction        | 0.0176     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.99      |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 11.5       |
# |    n_updates            | 19440      |
# |    policy_gradient_loss | -0.00425   |
# |    value_loss           | 31.7       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1946         |
# |    time_elapsed         | 8400         |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0002539443 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | -0.0405      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 140          |
# |    n_updates            | 19450        |
# |    policy_gradient_loss | 3.68e-05     |
# |    value_loss           | 515          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1947         |
# |    time_elapsed         | 8404         |
# |    total_timesteps      | 996864       |
# | train/                  |              |
# |    approx_kl            | 0.0046447115 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.89        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 90.1         |
# |    n_updates            | 19460        |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 184          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1948          |
# |    time_elapsed         | 8408          |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 0.00013331242 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.936        |
# |    explained_variance   | 0.677         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 95.9          |
# |    n_updates            | 19470         |
# |    policy_gradient_loss | -2.51e-05     |
# |    value_loss           | 222           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1949          |
# |    time_elapsed         | 8413          |
# |    total_timesteps      | 997888        |
# | train/                  |               |
# |    approx_kl            | 0.00026234367 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.915        |
# |    explained_variance   | 0.655         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 86.7          |
# |    n_updates            | 19480         |
# |    policy_gradient_loss | -0.000108     |
# |    value_loss           | 257           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1950         |
# |    time_elapsed         | 8417         |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0002622559 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.407        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 196          |
# |    n_updates            | 19490        |
# |    policy_gradient_loss | -0.000619    |
# |    value_loss           | 388          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1951         |
# |    time_elapsed         | 8421         |
# |    total_timesteps      | 998912       |
# | train/                  |              |
# |    approx_kl            | 0.0010163106 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.911       |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 105          |
# |    n_updates            | 19500        |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 354          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1952         |
# |    time_elapsed         | 8426         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0007501963 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 36           |
# |    n_updates            | 19510        |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 116          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 1953          |
# |    time_elapsed         | 8430          |
# |    total_timesteps      | 999936        |
# | train/                  |               |
# |    approx_kl            | 0.00091065955 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.94         |
# |    explained_variance   | 0.767         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 92.7          |
# |    n_updates            | 19520         |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 243           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 1954         |
# |    time_elapsed         | 8435         |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 7.432804e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.467        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 47.4         |
# |    n_updates            | 19530        |
# |    policy_gradient_loss | -0.000263    |
# |    value_loss           | 373          |
# ------------------------------------------

# %%
model.save('thisisatestmodel')

# %% [markdown]
# # 4. Test it Out

# %%
# Load model
model = PPO.load('./train/best_model_1000000')

# %%
state = env.reset()

# %%
# Start the game 
state = env.reset()
# Loop through the game
for step in range(5000): 
# while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# /home/daniel/.local/lib/python3.10/site-packages/gym_super_mario_bros/smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
